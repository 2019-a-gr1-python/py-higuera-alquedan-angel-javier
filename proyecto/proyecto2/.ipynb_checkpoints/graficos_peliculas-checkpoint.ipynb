# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import proyecto_analisis.import_data as analisis

# %% [markdown]
# ## Graficos de barras

# %%
analisis.top_revenue.plot.bar()
plt.show()

# %%
analisis.top_revenue_low.plot.bar()
plt.show()

# %%
analisis.top_budget.plot.bar()
plt.show()

# %%
analisis.top_budget_low.plot.bar()
plt.show()

# %%
analisis.top_rating.plot.bar()
plt.show()

# %%
analisis.top_rating_low.plot.bar()
plt.show()

# %%
analisis.top_actors.plot.bar()
plt.show()

# %%
analisis.top_actors_low.plot.bar()
plt.show()

# %%
analisis.top_genres.plot.bar()
plt.show()

# %%
analisis.top_genres_low.plot.bar()
plt.show()

# %%
analisis.top_directors.plot.bar()
plt.show()

# %%
analisis.top_directors_low.plot.bar()
plt.show()

# %%
analisis.top_writers.plot.bar()
plt.show()

# %%
analisis.top_writers_low.plot.bar()
plt.show()

# %%
analisis.top_languages.plot.bar()
plt.show()

# %%
analisis.top_languages_low.plot.bar()
plt.show()

# %%
analisis.top_runtime.plot.bar()
plt.show()

# %%
analisis.top_runtime_low.plot.bar()
plt.show()

# %% [markdown]
# ## Grafico PIE

# %%
analisis.percentage_genres.plot.pie()
print(analisis.percentage_genres)
plt.show()
# Out:
# 0
# Documentary          8.0
# TV Movie            10.0
# Western             26.0
# Music               29.0
# War                 61.0
# History             70.0
# Mystery            195.0
# Horror             229.0
# Animation          231.0
# Romance            254.0
# Family             308.0
# Fantasy            308.0
# Crime              313.0
# Science Fiction    350.0
# Adventure          551.0
# Comedy             591.0
# Thriller           602.0
# Action             701.0
# Drama              713.0
# Name: 1, dtype: float64

# %% [markdown]
# ## Averages

# %%
analisis.average_rating.plot.bar()
plt.show()

# %%
analisis.average_genres.plot.bar()
plt.show()

# %%
analisis.average_writers.plot.bar()
plt.show()

# %%
analisis.average_directors.plot.bar()
plt.show()

# %%
analisis.average_runtime.plot.bar()
plt.show()

# %%
analisis.average_budget.plot.bar()
plt.show()

# %%
analisis.average_revenue.plot.bar()
plt.show()

# %%
analisis.average_rating.plot.bar()
plt.show()
