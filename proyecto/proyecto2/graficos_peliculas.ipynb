# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import proyecto_analisis.import_data as analisis

# %% [markdown]
# ## Graficos de barras

# %%
analisis.top_revenue.plot.barh()
print(analisis.top_revenue)
plt.show()
# Out:
# 0
# Avengers: Endgame               2.792270e+09
# Avatar                          2.787965e+09
# Star Wars: The Force Awakens    2.068224e+09
# Avengers: Infinity War          2.046240e+09
# Titanic                         1.845034e+09
# Jurassic World                  1.671713e+09
# The Avengers                    1.519558e+09
# Furious 7                       1.506249e+09
# Avengers: Age of Ultron         1.405404e+09
# Black Panther                   1.346739e+09
# Name: 1, dtype: float64

# %%
analisis.top_revenue_low.plot.bar()
plt.show()

# %%
analisis.top_budget.plot.barh()
plt.show()

# %%
analisis.top_budget_low.plot.bar()
plt.show()

# %%
analisis.top_rating.plot.bar()
plt.show()

# %%
analisis.top_rating_low.plot.bar()
plt.show()

# %%
analisis.top_actors.plot.barh()
print(analisis.top_actors)
plt.show()
# Out:
# 0
# Frank Welker         53.0
# Samuel L. Jackson    47.0
# Bruce Willis         38.0
# Stan Lee             38.0
# Johnny Depp          37.0
# Liam Neeson          34.0
# Mickie McGowan       31.0
# Sherry Lynn          29.0
# Jason Statham        29.0
# Brad Pitt            28.0
# Name: 1, dtype: float64

# %%
analisis.top_actors_low.plot.bar()
plt.show()

# %%
analisis.top_genres.plot.barh()
plt.show()

# %%
analisis.top_genres_low.plot.bar()
plt.show()

# %%
analisis.top_directors.plot.bar()
plt.show()

# %%
analisis.top_directors_low.plot.bar()
plt.show()

# %%
analisis.top_writers.plot.bar()
plt.show()

# %%
analisis.top_writers_low.plot.bar()
plt.show()

# %%
analisis.top_languages.plot.barh()
plt.show()

# %%
analisis.top_languages.plot.pie()
plt.show()

# %%
analisis.top_languages_low.plot.bar()
plt.show()

# %%
analisis.top_runtime.plot.barh()
print(analisis.top_runtime)
plt.show()
# Out:
# 0
# Kill Bill: The Whole Bloody Affair               247.0
# Gone with the Wind                               233.0
# Once Upon a Time in America                      229.0
# Lawrence of Arabia                               217.0
# Ben-Hur                                          212.0
# Seven Samurai                                    207.0
# The Godfather: Part II                           202.0
# The Lord of the Rings: The Return of the King    201.0
# Spartacus                                        197.0
# Schindler's List                                 195.0
# Name: 1, dtype: float64

# %%
analisis.top_runtime_low.plot.barh()
plt.show()

# %% [markdown]
# ## Grafico PIE

# %%
analisis.percentage_genres.plot.pie()
print(analisis.percentage_genres)
plt.show()
# Out:
# 0
# Documentary          8.0
# TV Movie            10.0
# Western             26.0
# Music               29.0
# War                 61.0
# History             70.0
# Mystery            195.0
# Horror             229.0
# Animation          231.0
# Romance            254.0
# Family             308.0
# Fantasy            308.0
# Crime              313.0
# Science Fiction    350.0
# Adventure          551.0
# Comedy             591.0
# Thriller           602.0
# Action             701.0
# Drama              713.0
# Name: 1, dtype: float64

# %% [markdown]
# ## Averages

# %%
analisis.average_rating.plot.bar()
print(analisis.average_rating)
plt.show()
# Out:
# 0
# MAX    100.00000
# AVG     67.04156
# MIN     10.00000
# Name: 1, dtype: float64

# %%
analisis.average_genres.plot.bar()
print(analisis.average_genres)
plt.show()
# Out:
# 0
# MAX    713.000000
# AVG    292.105263
# MIN      8.000000
# Name: 1, dtype: float64

# %%
analisis.average_writers.plot.bar()
plt.show()

# %%
analisis.average_directors.plot.bar()
plt.show()

# %%
analisis.average_runtime.plot.bar()
print(analisis.average_runtime)
plt.show()
# Out:
# 0
# MAX    247.000000
# AVG    112.082564
# MIN      4.000000
# Name: 1, dtype: float64

# %%
analisis.average_budget.plot.bar()
plt.show()

# %%
analisis.average_revenue.plot.bar()
print(analisis.average_revenue) 
plt.show()
# Out:
# 0
# MAX    2.792270e+09
# AVG    2.267687e+08
# MIN    3.000000e+01
# Name: 1, dtype: float64

# %%
analisis.average_rating.plot.bar()
plt.show()
